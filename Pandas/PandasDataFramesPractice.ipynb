# %% [markdown]
# ## Basics

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
}, columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])
#The columns attribute is optional,using it to keep the same order.

# %%
df
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %%
df.index=[
    'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States'
]

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='str')

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='str')

# %%
df.info
# Out:
# <bound method DataFrame.info of                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America>

# %%
df.size
# Out:
# 35

# %%
df.shape
# Out:
# (7, 5)

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.dtypes
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent           str
# dtype: object

# %% [markdown]
# ## Indexing, Selection and Slicing

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.loc['Canada']
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: United States, dtype: object

# %%
df.loc[:,'Population']
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
df['Population']
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
df['Population'].to_frame() #Series converted to Data Frame
# Out:
#                 Population
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdom      64.511
# United States      318.523

# %%
df.loc[:,['Population','HDI']]
# Out:
#                 Population    HDI
# Canada              35.467  0.913
# France              63.951  0.888
# Germany             80.940  0.916
# Italy               60.665  0.873
# Japan              127.061  0.891
# United Kingdom      64.511  0.907
# United States      318.523  0.915

# %%
df[['Population','HDI']]
# Out:
#                 Population    HDI
# Canada              35.467  0.913
# France              63.951  0.888
# Germany             80.940  0.916
# Italy               60.665  0.873
# Japan              127.061  0.891
# United Kingdom      64.511  0.907
# United States      318.523  0.915

# %%
df[1:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %%
df.loc['Italy']
# Out:
# Population       60.665
# GDP             2167744
# Surface Area     301336
# HDI               0.873
# Continent        Europe
# Name: Italy, dtype: object

# %%
df.loc['France':'Italy']
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe

# %%
df.loc['France':'Italy','Population']
# Out:
# France     63.951
# Germany    80.940
# Italy      60.665
# Name: Population, dtype: float64

# %%
df.loc['France':'Italy',['Population' , 'GDP']]
# Out:
#          Population      GDP
# France       63.951  2833687
# Germany      80.940  3874437
# Italy        60.665  2167744

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.iloc[[0,1,-1]]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Canada             35.467   1785387       9984670  0.913   America
# France             63.951   2833687        640679  0.888    Europe
# United States     318.523  17348075       9525067  0.915   America

# %%
df.iloc[1:3,1]
# Out:
# France     2833687
# Germany    3874437
# Name: GDP, dtype: int64

# %%
df.iloc[1:4,[1,3]]
# Out:
#              GDP    HDI
# France   2833687  0.888
# Germany  3874437  0.916
# Italy    2167744  0.873

# %%
df.iloc[1:4, 1:4]
# Out:
#              GDP  Surface Area    HDI
# France   2833687        640679  0.888
# Germany  3874437        357114  0.916
# Italy    2167744        301336  0.873

# %% [markdown]
# #### Always use loc and iloc to reduce ambiguity, specially with DataFrames with numeric indexes.

# %% [markdown]
# ## Conditional selection (boolean arrays)

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df['Population']>70
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: Population, dtype: bool

# %%
df.loc[df['Population']>70]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany            80.940   3874437        357114  0.916    Europe
# Japan             127.061   4602367        377930  0.891      Asia
# United States     318.523  17348075       9525067  0.915   America

# %%
df[df['Population']>70] # this will give the answer but you can not performe below operation in this.
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany            80.940   3874437        357114  0.916    Europe
# Japan             127.061   4602367        377930  0.891      Asia
# United States     318.523  17348075       9525067  0.915   America

# %%
df.loc[df['Population']>70,'Population']
# Out:
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: Population, dtype: float64

# %%
df.loc[df['Population']>70,['Population','HDI']]
# Out:
#                Population    HDI
# Germany            80.940  0.916
# Japan             127.061  0.891
# United States     318.523  0.915

# %% [markdown]
# ## Dropping stuff

# %%
df.drop('Canada')
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(['Canada','Italy'])
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(columns=['Population','GDP'])
# Out:
#                 Surface Area    HDI Continent
# Canada               9984670  0.913   America
# France                640679  0.888    Europe
# Germany               357114  0.916    Europe
# Italy                 301336  0.873    Europe
# Japan                 377930  0.891      Asia
# United Kingdom        242495  0.907    Europe
# United States        9525067  0.915   America

# %%
df.drop(['Italy', 'Canada'], axis=0)
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(['Population', 'HDI'], axis=1)
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# Japan            4602367        377930      Asia
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %% [markdown]
# ## Operations

# %%
df[['Population', 'GDP']]
# Out:
#                 Population       GDP
# Canada              35.467   1785387
# France              63.951   2833687
# Germany             80.940   3874437
# Italy               60.665   2167744
# Japan              127.061   4602367
# United Kingdom      64.511   2950039
# United States      318.523  17348075

# %%
df[['Population', 'GDP']] / 100
# Out:
#                 Population        GDP
# Canada             0.35467   17853.87
# France             0.63951   28336.87
# Germany            0.80940   38744.37
# Italy              0.60665   21677.44
# Japan              1.27061   46023.67
# United Kingdom     0.64511   29500.39
# United States      3.18523  173480.75

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
crisis=pd.Series([-1000000,-0.3],index=['GDP','HDI'])
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[['GDP','HDI']]
# Out:
#                      GDP    HDI
# Canada           1785387  0.913
# France           2833687  0.888
# Germany          3874437  0.916
# Italy            2167744  0.873
# Japan            4602367  0.891
# United Kingdom   2950039  0.907
# United States   17348075  0.915

# %%
df[['GDP','HDI']] + crisis
# Out:
#                        GDP    HDI
# Canada            785387.0  0.613
# France           1833687.0  0.588
# Germany          2874437.0  0.616
# Italy            1167744.0  0.573
# Japan            3602367.0  0.591
# United Kingdom   1950039.0  0.607
# United States   16348075.0  0.615

# %% [markdown]
# ## Modifying DataFrames

# %%
langs = pd.Series(
    ['French', 'German', 'Italian'],
    index=['France', 'Germany', 'Italy'],
    name='Language'
)

# %%
langs
# Out:
# France      French
# Germany     German
# Italy      Italian
# Name: Language, dtype: str

# %%
df['Language']=langs

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# Canada              35.467   1785387       9984670  0.913   America      NaN
# France              63.951   2833687        640679  0.888    Europe   French
# Germany             80.940   3874437        357114  0.916    Europe   German
# Italy               60.665   2167744        301336  0.873    Europe  Italian
# Japan              127.061   4602367        377930  0.891      Asia      NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe      NaN
# United States      318.523  17348075       9525067  0.915   America      NaN

# %%
df['Language']='English'

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# Canada              35.467   1785387       9984670  0.913   America  English
# France              63.951   2833687        640679  0.888    Europe  English
# Germany             80.940   3874437        357114  0.916    Europe  English
# Italy               60.665   2167744        301336  0.873    Europe  English
# Japan              127.061   4602367        377930  0.891      Asia  English
# United Kingdom      64.511   2950039        242495  0.907    Europe  English
# United States      318.523  17348075       9525067  0.915   America  English

# %%
df.rename(
    columns={
        'HDI':"Human Devlopment Index",
        "Anual Popcorn Consumption":'APC'
    },index={
        "United States":'USA',
        "United Kingdom":'UK',
        'Argentina':'AR'
    }
)
# Out:
#          Population       GDP  Surface Area  Human Devlopment Index Continent  \
# Canada       35.467   1785387       9984670                   0.913   America
# France       63.951   2833687        640679                   0.888    Europe
# Germany      80.940   3874437        357114                   0.916    Europe
# Italy        60.665   2167744        301336                   0.873    Europe
# Japan       127.061   4602367        377930                   0.891      Asia
# UK           64.511   2950039        242495                   0.907    Europe
# USA         318.523  17348075       9525067                   0.915   America
#
#         Language
# Canada   English
# France   English
# Germany  English
# Italy    English
# Japan    English
# UK       English
# USA      English

# %%
df.rename(index=str.upper)
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# CANADA              35.467   1785387       9984670  0.913   America  English
# FRANCE              63.951   2833687        640679  0.888    Europe  English
# GERMANY             80.940   3874437        357114  0.916    Europe  English
# ITALY               60.665   2167744        301336  0.873    Europe  English
# JAPAN              127.061   4602367        377930  0.891      Asia  English
# UNITED KINGDOM      64.511   2950039        242495  0.907    Europe  English
# UNITED STATES      318.523  17348075       9525067  0.915   America  English

# %%
df.rename(index=lambda x: x.lower())
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# canada              35.467   1785387       9984670  0.913   America  English
# france              63.951   2833687        640679  0.888    Europe  English
# germany             80.940   3874437        357114  0.916    Europe  English
# italy               60.665   2167744        301336  0.873    Europe  English
# japan              127.061   4602367        377930  0.891      Asia  English
# united kingdom      64.511   2950039        242495  0.907    Europe  English
# united states      318.523  17348075       9525067  0.915   America  English

# %% [markdown]
# ## Adding values

# %%
df.loc['China'] = {'Population': 400.54, 'GDP': 3465723 , 'Continent':'Asia'}
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# Canada              35.467   1785387     9984670.0  0.913   America  English
# France              63.951   2833687      640679.0  0.888    Europe  English
# Germany             80.940   3874437      357114.0  0.916    Europe  English
# Italy               60.665   2167744      301336.0  0.873    Europe  English
# Japan              127.061   4602367      377930.0  0.891      Asia  English
# United Kingdom      64.511   2950039      242495.0  0.907    Europe  English
# United States      318.523  17348075     9525067.0  0.915   America  English
# China              400.540   3465723           NaN    NaN      Asia      NaN

# %%
df.drop('China',inplace=True)

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# Canada              35.467   1785387     9984670.0  0.913   America  English
# France              63.951   2833687      640679.0  0.888    Europe  English
# Germany             80.940   3874437      357114.0  0.916    Europe  English
# Italy               60.665   2167744      301336.0  0.873    Europe  English
# Japan              127.061   4602367      377930.0  0.891      Asia  English
# United Kingdom      64.511   2950039      242495.0  0.907    Europe  English
# United States      318.523  17348075     9525067.0  0.915   America  English

# %% [markdown]
# ## More radical index changes

# %%
df.reset_index()
# Out:
#             index  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387     9984670.0  0.913   America
# 1          France      63.951   2833687      640679.0  0.888    Europe
# 2         Germany      80.940   3874437      357114.0  0.916    Europe
# 3           Italy      60.665   2167744      301336.0  0.873    Europe
# 4           Japan     127.061   4602367      377930.0  0.891      Asia
# 5  United Kingdom      64.511   2950039      242495.0  0.907    Europe
# 6   United States     318.523  17348075     9525067.0  0.915   America
#
#   Language
# 0  English
# 1  English
# 2  English
# 3  English
# 4  English
# 5  English
# 6  English

# %%
df.set_index('Population')
# Out:
#                  GDP  Surface Area    HDI Continent Language
# Population
# 35.467       1785387     9984670.0  0.913   America  English
# 63.951       2833687      640679.0  0.888    Europe  English
# 80.940       3874437      357114.0  0.916    Europe  English
# 60.665       2167744      301336.0  0.873    Europe  English
# 127.061      4602367      377930.0  0.891      Asia  English
# 64.511       2950039      242495.0  0.907    Europe  English
# 318.523     17348075     9525067.0  0.915   America  English

# %% [markdown]
# ## Creating columns from other columns

# %%
df[['Population','GDP']]
# Out:
#                 Population       GDP
# Canada              35.467   1785387
# France              63.951   2833687
# Germany             80.940   3874437
# Italy               60.665   2167744
# Japan              127.061   4602367
# United Kingdom      64.511   2950039
# United States      318.523  17348075

# %%
df['GDP']/df['Population']
# Out:
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United States     54464.120330
# dtype: float64

# %%
df["Per Capita Income"]=df['GDP']/df['Population']

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language  \
# Canada              35.467   1785387     9984670.0  0.913   America  English
# France              63.951   2833687      640679.0  0.888    Europe  English
# Germany             80.940   3874437      357114.0  0.916    Europe  English
# Italy               60.665   2167744      301336.0  0.873    Europe  English
# Japan              127.061   4602367      377930.0  0.891      Asia  English
# United Kingdom      64.511   2950039      242495.0  0.907    Europe  English
# United States      318.523  17348075     9525067.0  0.915   America  English
#
#                 Per Capita Income
# Canada               50339.385908
# France               44310.284437
# Germany              47868.013343
# Italy                35733.025633
# Japan                36221.712406
# United Kingdom       45729.239975
# United States        54464.120330

# %% [markdown]
# ## Statistical info

# %%
df.head()
# Out:
#          Population      GDP  Surface Area    HDI Continent Language  \
# Canada       35.467  1785387     9984670.0  0.913   America  English
# France       63.951  2833687      640679.0  0.888    Europe  English
# Germany      80.940  3874437      357114.0  0.916    Europe  English
# Italy        60.665  2167744      301336.0  0.873    Europe  English
# Japan       127.061  4602367      377930.0  0.891      Asia  English
#
#          Per Capita Income
# Canada        50339.385908
# France        44310.284437
# Germany       47868.013343
# Italy         35733.025633
# Japan         36221.712406

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI  Per Capita Income
# count    7.000000  7.000000e+00  7.000000e+00  7.000000           7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429       44952.254576
# std     97.249970  5.494020e+06  4.576187e+06  0.016592        6954.983875
# min     35.467000  1.785387e+06  2.424950e+05  0.873000       35733.025633
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500       40265.998421
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000       45729.239975
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000       49103.699626
# max    318.523000  1.734808e+07  9.984670e+06  0.916000       54464.120330

# %%
population=df['Population']

# %%
population.min(),population.max()
# Out:
# (np.float64(35.467), np.float64(318.523))

# %%
population.sum()
# Out:
# np.float64(751.118)

# %%
population.sum()/len(population)
# Out:
# np.float64(107.30257142857144)

# %%
population.mean()
# Out:
# np.float64(107.30257142857144)

# %%
population.std()
# Out:
# np.float64(97.24996987121581)

# %%
population.var()
# Out:
# np.float64(9457.556639952383)

# %%
population.median()
# Out:
# np.float64(64.511)

# %%
population.describe()
# Out:
# count      7.000000
# mean     107.302571
# std       97.249970
# min       35.467000
# 25%       62.308000
# 50%       64.511000
# 75%      104.000500
# max      318.523000
# Name: Population, dtype: float64

# %%
population.quantile(.25)
# Out:
# np.float64(62.308)

# %%
population.quantile([.2, .4, .6, .8, 1])
# Out:
# 0.2     61.3222
# 0.4     64.1750
# 0.6     74.3684
# 0.8    117.8368
# 1.0    318.5230
# Name: Population, dtype: float64
